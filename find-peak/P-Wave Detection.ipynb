# %%
import numpy as np
import matplotlib.pyplot as plt
import pywt

# %%
sample  = np.load('./smc_numpy_data/II/2021_94554.npy')

# %%
plt.plot(sample[500:1000])
plt.show()

# %%
np.argmax(sample[600:700])
# Out:
# 40

# %%
plt.plot(np.arctan(sample[500:1000]))
plt.show()

# %%
np.argmax(np.arctan(sample[600:700]))
# Out:
# 40

# %%
np.diff(sample)
# Out:
# array([518.,  80.,  10., ...,   0.,   0.,   1.], dtype=float32)
